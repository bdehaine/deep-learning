# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# The epsilon is essential as it gives the agent the chance to explore different paths that may improve its policy. Otherwise the agent could stick to a soboptimal policy.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=100 # set small when debugging
epochs_test=15# set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# The array position represents the position of the agent on the grid.
# The bord position represents the position of bonus and malus on the grid.

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(self.n_action)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will end
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action (random action in this case)
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)
        
        # Save as a mp4
        env.draw(prefix+str(e))

        # Update stats
        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos('random0.mp4'))
# Out:
# Win/lose count 11.0/19.0. Average score (-8.0)
# Win/lose count 11.5/15.0. Average score (-5.75)
# Win/lose count 9.0/12.0. Average score (-4.833333333333333)
# Win/lose count 7.5/12.0. Average score (-4.75)
# Win/lose count 11.0/13.0. Average score (-4.2)
# Win/lose count 6.0/15.0. Average score (-5.0)
# Win/lose count 9.5/15.0. Average score (-5.071428571428571)
# Win/lose count 13.0/17.0. Average score (-4.9375)
# Win/lose count 10.0/11.0. Average score (-4.5)
# Win/lose count 8.5/14.0. Average score (-4.6)
# Win/lose count 7.0/19.0. Average score (-5.2727272727272725)
# Win/lose count 5.0/8.0. Average score (-5.083333333333333)
# Win/lose count 7.0/7.0. Average score (-4.6923076923076925)
# Win/lose count 9.0/14.0. Average score (-4.714285714285714)
# Win/lose count 13.5/20.0. Average score (-4.833333333333333)
# Win/lose count 12.0/22.0. Average score (-5.15625)
# Win/lose count 9.0/14.0. Average score (-5.147058823529412)
# Win/lose count 12.0/11.0. Average score (-4.805555555555555)
# Win/lose count 8.0/10.0. Average score (-4.657894736842105)
# Win/lose count 9.5/14.0. Average score (-4.65)
# Win/lose count 8.5/9.0. Average score (-4.4523809523809526)
# Win/lose count 6.0/5.0. Average score (-4.204545454545454)
# Win/lose count 8.0/15.0. Average score (-4.326086956521739)
# Win/lose count 8.0/4.0. Average score (-3.9791666666666665)
# Win/lose count 11.0/14.0. Average score (-3.94)
# Win/lose count 12.5/9.0. Average score (-3.6538461538461537)
# Win/lose count 10.0/11.0. Average score (-3.5555555555555554)
# Win/lose count 6.5/13.0. Average score (-3.6607142857142856)
# Win/lose count 8.5/12.0. Average score (-3.6551724137931036)
# Win/lose count 6.5/7.0. Average score (-3.55)
# Final score: -3.55
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max_{a'} Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# __ANSWER__
#
#
# We have:
#
# \begin{equation*}
# \begin{split}
# Q^{\pi}(s,a)&=E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]\\
# &=E_{p^{\pi}}[r(s, a)+\sum_{t=1}^{\infty}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a]\\
# &=E_{p^{\pi}}[r(s, a)+\gamma\sum_{t=0}^{\infty}\gamma^{t}r(s_{t+1},a_{t+1})|s_{0}=s,a_{0}=a]\\
# &=E_{p^{\pi}}\left[r(s, a)+\gamma E_{(s',a')\sim p(.|s,a)} [\sum_{t=0}^{\infty}\gamma^{t}r(s_{t+1},a_{t+1})|s_1=s', a_1=a']\right]\\
# &=E_{(s',a')\sim p(.|s,a)}\left[r(s, a)+\gamma E_{p^{\pi}}[\sum_{t=0}^{\infty}\gamma^{t}r(s_{t+1},a_{t+1})|s_1=s', a_1=a']\right]\\
# &=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{split}
# \end{equation*}

# %% [markdown]
# Then:
# \begin{equation*}
# \begin{split}
# Q^{*}(s,a)&=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{*}(s',a')]\\
# &\leq E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')]\\
# &\leq E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')]\\
# &\leq Q^{\pi^{*}(s)}(s, a)
# \end{split}
# \end{equation*}

# %% [markdown]
# with $ \pi^{*}(s) $ the optimal policy for a given s:
# \begin{equation*}
# \pi^{*}(s)=\text{argmax}_a Q^{*}(s,a)
# \end{equation*}
#
# Since $Q^{*}$ is optimal, the inequalities become equalities and we have:
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
#
# A natural loss is to compare $Q(s,a,\theta)$ with $ E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q(s',a', \theta)]$.
#
# Therefore a plausible objective is:
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max_{a'} Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        self.memory.append(m)
        # if memory is full, we keep the latest moves
        self.memory = self.memory[-self.max_memory:]

    def random_access(self):
        return self.memory[np.random.randint(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(s.reshape(1, 5, 5, self.n_state)))
    
    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            #memory = self.memory.random_access()
            s, n_s, a, r, game_over = self.memory.random_access()
            if game_over_:
                target_q[i, a] = r
            else:
                target_q[i, a] = r + self.discount*np.max(self.model.predict(n_s.reshape(1, 5, 5, self.n_state)).reshape(-1))
            
            input_states[i] = s
        
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)

        l = self.model.train_on_batch(input_states, target_q)
        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        model = Sequential()
        model.add(Reshape((-1,), input_shape=(5, 5, self.n_state)))
        model.add(Dense(self.n_action))
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 16)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train10.mp4'))
# Out:
# Epoch 000/100 | Loss 0.1198 | Win/lose count 5.5/8.0 (-2.5)
# Epoch 001/100 | Loss 0.0146 | Win/lose count 1.5/6.0 (-4.5)
# Epoch 002/100 | Loss 0.0325 | Win/lose count 2.0/0 (2.0)
# Epoch 003/100 | Loss 0.0087 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 004/100 | Loss 0.0050 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 005/100 | Loss 0.0036 | Win/lose count 4.0/3.0 (1.0)
# Epoch 006/100 | Loss 0.0177 | Win/lose count 4.5/3.0 (1.5)
# Epoch 007/100 | Loss 0.0149 | Win/lose count 12.0/7.0 (5.0)
# Epoch 008/100 | Loss 0.0062 | Win/lose count 4.0/4.0 (0.0)
# Epoch 009/100 | Loss 0.0021 | Win/lose count 5.0/2.0 (3.0)
# Epoch 010/100 | Loss 0.0038 | Win/lose count 11.0/7.0 (4.0)
# Epoch 011/100 | Loss 0.0200 | Win/lose count 2.5/0 (2.5)
# Epoch 012/100 | Loss 0.0093 | Win/lose count 6.0/6.0 (0.0)
# Epoch 013/100 | Loss 0.0057 | Win/lose count 7.0/1.0 (6.0)
# Epoch 014/100 | Loss 0.0096 | Win/lose count 10.5/3.0 (7.5)
# Epoch 015/100 | Loss 0.0077 | Win/lose count 8.0/3.0 (5.0)
# Epoch 016/100 | Loss 0.0225 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 017/100 | Loss 0.0184 | Win/lose count 7.0/3.0 (4.0)
# Epoch 018/100 | Loss 0.0035 | Win/lose count 9.0/1.0 (8.0)
# Epoch 019/100 | Loss 0.0040 | Win/lose count 7.0/3.0 (4.0)
# Epoch 020/100 | Loss 0.0185 | Win/lose count 4.0/4.0 (0.0)
# Epoch 021/100 | Loss 0.0048 | Win/lose count 4.0/2.0 (2.0)
# Epoch 022/100 | Loss 0.0067 | Win/lose count 8.0/6.0 (2.0)
# Epoch 023/100 | Loss 0.0220 | Win/lose count 3.5/1.0 (2.5)
# Epoch 024/100 | Loss 0.0042 | Win/lose count 6.5/1.0 (5.5)
# Epoch 025/100 | Loss 0.0050 | Win/lose count 5.0/1.0 (4.0)
# Epoch 026/100 | Loss 0.0164 | Win/lose count 3.0/1.0 (2.0)
# Epoch 027/100 | Loss 0.0042 | Win/lose count 2.0/1.0 (1.0)
# Epoch 028/100 | Loss 0.0060 | Win/lose count 8.0/4.0 (4.0)
# Epoch 029/100 | Loss 0.0031 | Win/lose count 7.0/3.0 (4.0)
# Epoch 030/100 | Loss 0.0045 | Win/lose count 5.5/5.0 (0.5)
# Epoch 031/100 | Loss 0.0022 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 032/100 | Loss 0.0042 | Win/lose count 3.0/1.0 (2.0)
# Epoch 033/100 | Loss 0.0046 | Win/lose count 6.5/4.0 (2.5)
# Epoch 034/100 | Loss 0.0037 | Win/lose count 2.0/1.0 (1.0)
# Epoch 035/100 | Loss 0.0017 | Win/lose count 8.5/5.0 (3.5)
# Epoch 036/100 | Loss 0.0164 | Win/lose count 4.0/6.0 (-2.0)
# Epoch 037/100 | Loss 0.0017 | Win/lose count 3.5/2.0 (1.5)
# Epoch 038/100 | Loss 0.0015 | Win/lose count 10.0/2.0 (8.0)
# Epoch 039/100 | Loss 0.0019 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 040/100 | Loss 0.0320 | Win/lose count 5.5/2.0 (3.5)
# Epoch 041/100 | Loss 0.0036 | Win/lose count 8.0/1.0 (7.0)
# Epoch 042/100 | Loss 0.0042 | Win/lose count 10.5/7.0 (3.5)
# Epoch 043/100 | Loss 0.0031 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 044/100 | Loss 0.0049 | Win/lose count 10.0/7.0 (3.0)
# Epoch 045/100 | Loss 0.0026 | Win/lose count 2.5/1.0 (1.5)
# Epoch 046/100 | Loss 0.0049 | Win/lose count 10.0/5.0 (5.0)
# Epoch 047/100 | Loss 0.0032 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 048/100 | Loss 0.0031 | Win/lose count 5.5/5.0 (0.5)
# Epoch 049/100 | Loss 0.0179 | Win/lose count 7.5/5.0 (2.5)
# Epoch 050/100 | Loss 0.0052 | Win/lose count 6.0/5.0 (1.0)
# Epoch 051/100 | Loss 0.0187 | Win/lose count 2.5/2.0 (0.5)
# Epoch 052/100 | Loss 0.0195 | Win/lose count 4.0/3.0 (1.0)
# Epoch 053/100 | Loss 0.0020 | Win/lose count 1.5/1.0 (0.5)
# Epoch 054/100 | Loss 0.0017 | Win/lose count 7.5/4.0 (3.5)
# Epoch 055/100 | Loss 0.0205 | Win/lose count 4.5/2.0 (2.5)
# Epoch 056/100 | Loss 0.0040 | Win/lose count 7.0/1.0 (6.0)
# Epoch 057/100 | Loss 0.0037 | Win/lose count 5.5/8.0 (-2.5)
# Epoch 058/100 | Loss 0.0026 | Win/lose count 8.5/4.0 (4.5)
# Epoch 059/100 | Loss 0.0045 | Win/lose count 5.5/4.0 (1.5)
# Epoch 060/100 | Loss 0.0017 | Win/lose count 6.0/1.0 (5.0)
# Epoch 061/100 | Loss 0.0047 | Win/lose count 9.0/4.0 (5.0)
# Epoch 062/100 | Loss 0.0060 | Win/lose count 5.0/2.0 (3.0)
# Epoch 063/100 | Loss 0.0025 | Win/lose count 7.0/2.0 (5.0)
# Epoch 064/100 | Loss 0.0021 | Win/lose count 7.0/4.0 (3.0)
# Epoch 065/100 | Loss 0.0057 | Win/lose count 7.0/1.0 (6.0)
# Epoch 066/100 | Loss 0.0366 | Win/lose count 7.0/5.0 (2.0)
# Epoch 067/100 | Loss 0.0064 | Win/lose count 6.5/2.0 (4.5)
# Epoch 068/100 | Loss 0.0048 | Win/lose count 12.0/2.0 (10.0)
# Epoch 069/100 | Loss 0.0042 | Win/lose count 3.0/0 (3.0)
# Epoch 070/100 | Loss 0.0068 | Win/lose count 5.0/1.0 (4.0)
# Epoch 071/100 | Loss 0.0033 | Win/lose count 5.5/6.0 (-0.5)
# Epoch 072/100 | Loss 0.0034 | Win/lose count 9.5/6.0 (3.5)
# Epoch 073/100 | Loss 0.0045 | Win/lose count 2.0/0 (2.0)
# Epoch 074/100 | Loss 0.0202 | Win/lose count 6.5/9.0 (-2.5)
# Epoch 075/100 | Loss 0.0027 | Win/lose count 8.0/3.0 (5.0)
# Epoch 076/100 | Loss 0.0024 | Win/lose count 7.0/4.0 (3.0)
# Epoch 077/100 | Loss 0.0042 | Win/lose count 9.0/4.0 (5.0)
# Epoch 078/100 | Loss 0.0056 | Win/lose count 5.0/1.0 (4.0)
# Epoch 079/100 | Loss 0.0238 | Win/lose count 8.5/5.0 (3.5)
# Epoch 080/100 | Loss 0.0034 | Win/lose count 11.0/1.0 (10.0)
# Epoch 081/100 | Loss 0.0258 | Win/lose count 8.5/5.0 (3.5)
# Epoch 082/100 | Loss 0.0220 | Win/lose count 9.5/4.0 (5.5)
# Epoch 083/100 | Loss 0.0069 | Win/lose count 6.5/2.0 (4.5)
# Epoch 084/100 | Loss 0.0066 | Win/lose count 3.0/3.0 (0.0)
# Epoch 085/100 | Loss 0.0378 | Win/lose count 11.5/1.0 (10.5)
# Epoch 086/100 | Loss 0.0072 | Win/lose count 8.5/4.0 (4.5)
# Epoch 087/100 | Loss 0.0309 | Win/lose count 6.0/4.0 (2.0)
# Epoch 088/100 | Loss 0.0587 | Win/lose count 7.0/4.0 (3.0)
# Epoch 089/100 | Loss 0.0231 | Win/lose count 7.0/0 (7.0)
# Epoch 090/100 | Loss 0.0075 | Win/lose count 4.0/1.0 (3.0)
# Epoch 091/100 | Loss 0.0100 | Win/lose count 4.5/3.0 (1.5)
# Epoch 092/100 | Loss 0.0075 | Win/lose count 3.0/9.0 (-6.0)
# Epoch 093/100 | Loss 0.0087 | Win/lose count 7.5/2.0 (5.5)
# Epoch 094/100 | Loss 0.0081 | Win/lose count 7.0/4.0 (3.0)
# Epoch 095/100 | Loss 0.0072 | Win/lose count 7.0/2.0 (5.0)
# Epoch 096/100 | Loss 0.0070 | Win/lose count 9.0/4.0 (5.0)
# Epoch 097/100 | Loss 0.0079 | Win/lose count 5.5/3.0 (2.5)
# Epoch 098/100 | Loss 0.0085 | Win/lose count 6.0/2.0 (4.0)
# Epoch 099/100 | Loss 0.0218 | Win/lose count 3.5/4.0 (-0.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        model = Sequential()
        model.add(Conv2D(32, (3,3),input_shape=(5, 5, self.n_state),padding='same'))
        model.add(Conv2D(64,(3,3)))#,padding='same'))#
        model.add(Flatten())
        model.add(Dense(self.n_action))
        

        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        model.summary()
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.05, epsilon = 0.1, memory_size=2000, batch_size = 16)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train10.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 4)                 2308
# =================================================================
# Total params: 21,412
# Trainable params: 21,412
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/100 | Loss 0.0086 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 001/100 | Loss 0.0276 | Win/lose count 6.0/3.0 (3.0)
# Epoch 002/100 | Loss 0.0032 | Win/lose count 3.0/2.0 (1.0)
# Epoch 003/100 | Loss 0.0075 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 004/100 | Loss 0.0037 | Win/lose count 8.5/6.0 (2.5)
# Epoch 005/100 | Loss 0.0378 | Win/lose count 3.0/2.0 (1.0)
# Epoch 006/100 | Loss 0.0113 | Win/lose count 3.5/0 (3.5)
# Epoch 007/100 | Loss 0.0036 | Win/lose count 3.5/1.0 (2.5)
# Epoch 008/100 | Loss 0.0228 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 009/100 | Loss 0.0046 | Win/lose count 7.5/2.0 (5.5)
# Epoch 010/100 | Loss 0.0027 | Win/lose count 3.0/2.0 (1.0)
# Epoch 011/100 | Loss 0.0048 | Win/lose count 8.0/1.0 (7.0)
# Epoch 012/100 | Loss 0.0040 | Win/lose count 7.0/1.0 (6.0)
# Epoch 013/100 | Loss 0.0045 | Win/lose count 4.5/7.0 (-2.5)
# Epoch 014/100 | Loss 0.0112 | Win/lose count 2.0/0 (2.0)
# Epoch 015/100 | Loss 0.0037 | Win/lose count 3.5/0 (3.5)
# Epoch 016/100 | Loss 0.0179 | Win/lose count 3.0/2.0 (1.0)
# Epoch 017/100 | Loss 0.0135 | Win/lose count 4.5/6.0 (-1.5)
# Epoch 018/100 | Loss 0.0102 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 019/100 | Loss 0.0171 | Win/lose count 4.5/4.0 (0.5)
# Epoch 020/100 | Loss 0.0027 | Win/lose count 6.5/4.0 (2.5)
# Epoch 021/100 | Loss 0.0022 | Win/lose count 4.0/1.0 (3.0)
# Epoch 022/100 | Loss 0.0024 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 023/100 | Loss 0.0044 | Win/lose count 4.5/1.0 (3.5)
# Epoch 024/100 | Loss 0.0075 | Win/lose count 7.5/4.0 (3.5)
# Epoch 025/100 | Loss 0.0042 | Win/lose count 2.0/1.0 (1.0)
# Epoch 026/100 | Loss 0.0022 | Win/lose count 5.0/0 (5.0)
# Epoch 027/100 | Loss 0.0023 | Win/lose count 4.0/1.0 (3.0)
# Epoch 028/100 | Loss 0.0031 | Win/lose count 1.5/5.0 (-3.5)
# Epoch 029/100 | Loss 0.0250 | Win/lose count 5.0/1.0 (4.0)
# Epoch 030/100 | Loss 0.0039 | Win/lose count 2.5/0 (2.5)
# Epoch 031/100 | Loss 0.0019 | Win/lose count 2.5/1.0 (1.5)
# Epoch 032/100 | Loss 0.0200 | Win/lose count 3.5/1.0 (2.5)
# Epoch 033/100 | Loss 0.0095 | Win/lose count 6.0/2.0 (4.0)
# Epoch 034/100 | Loss 0.0012 | Win/lose count 4.5/1.0 (3.5)
# Epoch 035/100 | Loss 0.0007 | Win/lose count 4.0/2.0 (2.0)
# Epoch 036/100 | Loss 0.0027 | Win/lose count 4.5/1.0 (3.5)
# Epoch 037/100 | Loss 0.0014 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 038/100 | Loss 0.0007 | Win/lose count 5.0/4.0 (1.0)
# Epoch 039/100 | Loss 0.0053 | Win/lose count 5.0/3.0 (2.0)
# Epoch 040/100 | Loss 0.0035 | Win/lose count 2.0/2.0 (0.0)
# Epoch 041/100 | Loss 0.0059 | Win/lose count 2.5/1.0 (1.5)
# Epoch 042/100 | Loss 0.0011 | Win/lose count 3.0/1.0 (2.0)
# Epoch 043/100 | Loss 0.0023 | Win/lose count 3.0/1.0 (2.0)
# Epoch 044/100 | Loss 0.0024 | Win/lose count 6.0/1.0 (5.0)
# Epoch 045/100 | Loss 0.0021 | Win/lose count 2.0/2.0 (0.0)
# Epoch 046/100 | Loss 0.0149 | Win/lose count 3.0/1.0 (2.0)
# Epoch 047/100 | Loss 0.0166 | Win/lose count 4.0/1.0 (3.0)
# Epoch 048/100 | Loss 0.0015 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 049/100 | Loss 0.0015 | Win/lose count 3.0/2.0 (1.0)
# Epoch 050/100 | Loss 0.0189 | Win/lose count 4.0/2.0 (2.0)
# Epoch 051/100 | Loss 0.0066 | Win/lose count 3.5/1.0 (2.5)
# Epoch 052/100 | Loss 0.0074 | Win/lose count 3.0/0 (3.0)
# Epoch 053/100 | Loss 0.0211 | Win/lose count 3.5/0 (3.5)
# Epoch 054/100 | Loss 0.0008 | Win/lose count 4.0/4.0 (0.0)
# Epoch 055/100 | Loss 0.0054 | Win/lose count 3.0/7.0 (-4.0)
# Epoch 056/100 | Loss 0.0040 | Win/lose count 5.0/4.0 (1.0)
# Epoch 057/100 | Loss 0.0196 | Win/lose count 2.5/7.0 (-4.5)
# Epoch 058/100 | Loss 0.0018 | Win/lose count 5.0/4.0 (1.0)
# Epoch 059/100 | Loss 0.0047 | Win/lose count 6.0/1.0 (5.0)
# Epoch 060/100 | Loss 0.0010 | Win/lose count 4.0/2.0 (2.0)
# Epoch 061/100 | Loss 0.0164 | Win/lose count 6.0/2.0 (4.0)
# Epoch 062/100 | Loss 0.0203 | Win/lose count 4.5/5.0 (-0.5)
# Epoch 063/100 | Loss 0.0179 | Win/lose count 5.0/4.0 (1.0)
# Epoch 064/100 | Loss 0.0058 | Win/lose count 3.5/1.0 (2.5)
# Epoch 065/100 | Loss 0.0038 | Win/lose count 6.0/4.0 (2.0)
# Epoch 066/100 | Loss 0.0027 | Win/lose count 6.0/1.0 (5.0)
# Epoch 067/100 | Loss 0.0023 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 068/100 | Loss 0.0043 | Win/lose count 2.0/2.0 (0.0)
# Epoch 069/100 | Loss 0.0031 | Win/lose count 5.0/4.0 (1.0)
# Epoch 070/100 | Loss 0.0018 | Win/lose count 5.5/2.0 (3.5)
# Epoch 071/100 | Loss 0.0052 | Win/lose count 3.5/3.0 (0.5)
# Epoch 072/100 | Loss 0.0257 | Win/lose count 4.5/6.0 (-1.5)
# Epoch 073/100 | Loss 0.0011 | Win/lose count 6.0/3.0 (3.0)
# Epoch 074/100 | Loss 0.0022 | Win/lose count 2.0/6.0 (-4.0)
# Epoch 075/100 | Loss 0.0181 | Win/lose count 5.0/4.0 (1.0)
# Epoch 076/100 | Loss 0.0015 | Win/lose count 3.0/8.0 (-5.0)
# Epoch 077/100 | Loss 0.0038 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 078/100 | Loss 0.0042 | Win/lose count 7.5/3.0 (4.5)
# Epoch 079/100 | Loss 0.0012 | Win/lose count 3.5/3.0 (0.5)
# Epoch 080/100 | Loss 0.0158 | Win/lose count 4.5/3.0 (1.5)
# Epoch 081/100 | Loss 0.0011 | Win/lose count 2.5/2.0 (0.5)
# Epoch 082/100 | Loss 0.0018 | Win/lose count 6.0/0 (6.0)
# Epoch 083/100 | Loss 0.0071 | Win/lose count 8.5/3.0 (5.5)
# Epoch 084/100 | Loss 0.0076 | Win/lose count 8.0/3.0 (5.0)
# Epoch 085/100 | Loss 0.0014 | Win/lose count 6.0/4.0 (2.0)
# Epoch 086/100 | Loss 0.0008 | Win/lose count 4.0/1.0 (3.0)
# Epoch 087/100 | Loss 0.0037 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 088/100 | Loss 0.0020 | Win/lose count 4.5/1.0 (3.5)
# Epoch 089/100 | Loss 0.0027 | Win/lose count 7.5/2.0 (5.5)
# Epoch 090/100 | Loss 0.0179 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 091/100 | Loss 0.0181 | Win/lose count 6.5/1.0 (5.5)
# Epoch 092/100 | Loss 0.0089 | Win/lose count 4.5/2.0 (2.5)
# Epoch 093/100 | Loss 0.0016 | Win/lose count 9.5/4.0 (5.5)
# Epoch 094/100 | Loss 0.0012 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 095/100 | Loss 0.0174 | Win/lose count 3.5/4.0 (-0.5)
# Epoch 096/100 | Loss 0.0021 | Win/lose count 4.5/1.0 (3.5)
# Epoch 097/100 | Loss 0.0058 | Win/lose count 7.0/7.0 (0.0)
# Epoch 098/100 | Loss 0.0015 | Win/lose count 9.5/1.0 (8.5)
# Epoch 099/100 | Loss 0.0010 | Win/lose count 6.0/2.0 (4.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 4)                 2308
# =================================================================
# Total params: 21,412
# Trainable params: 21,412
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 9.5/1.0. Average score (8.5)
# Win/lose count 7.0/2.0. Average score (6.75)
# Win/lose count 6.0/4.0. Average score (5.166666666666667)
# Win/lose count 3.0/5.0. Average score (3.375)
# Win/lose count 7.5/2.0. Average score (3.8)
# Win/lose count 6.5/4.0. Average score (3.5833333333333335)
# Win/lose count 9.0/2.0. Average score (4.071428571428571)
# Win/lose count 8.5/4.0. Average score (4.125)
# Win/lose count 5.0/7.0. Average score (3.4444444444444446)
# Win/lose count 6.5/4.0. Average score (3.35)
# Win/lose count 7.0/4.0. Average score (3.3181818181818183)
# Win/lose count 10.5/5.0. Average score (3.5)
# Win/lose count 8.5/8.0. Average score (3.269230769230769)
# Win/lose count 8.0/3.0. Average score (3.392857142857143)
# Win/lose count 11.5/6.0. Average score (3.533333333333333)
# Win/lose count 5.5/3.0. Average score (3.46875)
# Win/lose count 7.0/1.0. Average score (3.6176470588235294)
# Win/lose count 7.0/3.0. Average score (3.638888888888889)
# Win/lose count 9.0/2.0. Average score (3.8157894736842106)
# Win/lose count 2.5/1.0. Average score (3.7)
# Win/lose count 7.5/3.0. Average score (3.738095238095238)
# Win/lose count 6.0/1.0. Average score (3.7954545454545454)
# Win/lose count 11.5/3.0. Average score (4.0)
# Win/lose count 11.0/3.0. Average score (4.166666666666667)
# Win/lose count 6.5/3.0. Average score (4.14)
# Win/lose count 4.5/1.0. Average score (4.115384615384615)
# Win/lose count 4.0/3.0. Average score (4.0)
# Win/lose count 5.5/2.0. Average score (3.982142857142857)
# Win/lose count 2.5/1.0. Average score (3.896551724137931)
# Win/lose count 3.5/5.0. Average score (3.716666666666667)
# Final score: 3.716666666666667
# Test of the FC
# Win/lose count 4.0/11.0. Average score (-7.0)
# Win/lose count 5.5/10.0. Average score (-5.75)
# Win/lose count 1.5/5.0. Average score (-5.0)
# Win/lose count 3.0/6.0. Average score (-4.5)
# Win/lose count 8.5/6.0. Average score (-3.1)
# Win/lose count 2.0/3.0. Average score (-2.75)
# Win/lose count 4.5/2.0. Average score (-2.0)
# Win/lose count 5.5/2.0. Average score (-1.3125)
# Win/lose count 3.5/3.0. Average score (-1.1111111111111112)
# Win/lose count 5.5/4.0. Average score (-0.85)
# Win/lose count 3.0/5.0. Average score (-0.9545454545454546)
# Win/lose count 4.0/2.0. Average score (-0.7083333333333334)
# Win/lose count 6.0/2.0. Average score (-0.34615384615384615)
# Win/lose count 8.0/3.0. Average score (0.03571428571428571)
# Win/lose count 6.0/0. Average score (0.43333333333333335)
# Win/lose count 12.0/3.0. Average score (0.96875)
# Win/lose count 7.0/5.0. Average score (1.0294117647058822)
# Win/lose count 2.0/2.0. Average score (0.9722222222222222)
# Win/lose count 8.5/2.0. Average score (1.263157894736842)
# Win/lose count 7.5/1.0. Average score (1.525)
# Win/lose count 7.0/5.0. Average score (1.5476190476190477)
# Win/lose count 5.0/5.0. Average score (1.4772727272727273)
# Win/lose count 4.0/4.0. Average score (1.4130434782608696)
# Win/lose count 5.0/1.0. Average score (1.5208333333333333)
# Win/lose count 3.5/4.0. Average score (1.44)
# Win/lose count 0.5/1.0. Average score (1.3653846153846154)
# Win/lose count 5.5/3.0. Average score (1.4074074074074074)
# Win/lose count 4.0/2.0. Average score (1.4285714285714286)
# Win/lose count 5.5/0. Average score (1.5689655172413792)
# Win/lose count 2.5/3.0. Average score (1.5)
# Final score: 1.5

# %%
HTML(display_videos('cnn_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
HTML(display_videos('fc_test10.mp4'))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# We can see that the CNN performs better. An issue that we can observe is that the agent gets stuck in a loop when it is surrounded with empty cells.

# %%
for temp in [0.1,0.5,0.9]:
    print('-------------------- Temperature : {} ---------------'.format(temp))
    env = Environment(grid_size=size, max_time=T,temperature=temp)
    agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
    agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

    agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
    agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
    
    print('Test of the CNN')
    test(agent_cnn,env,epochs_test,prefix='cnn_test')
    print('Test of the FC')
    test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# -------------------- Temperature : 0.1 ---------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_35 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 4)                 2308
# =================================================================
# Total params: 21,412
# Trainable params: 21,412
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 3.5/1.0. Average score (2.5)
# Win/lose count 3.0/1.0. Average score (2.25)
# Win/lose count 1.5/1.0. Average score (1.6666666666666667)
# Win/lose count 2.5/3.0. Average score (1.125)
# Win/lose count 4.0/2.0. Average score (1.3)
# Win/lose count 4.5/4.0. Average score (1.1666666666666667)
# Win/lose count 2.0/1.0. Average score (1.1428571428571428)
# Win/lose count 4.0/0. Average score (1.5)
# Win/lose count 3.0/1.0. Average score (1.5555555555555556)
# Win/lose count 1.5/4.0. Average score (1.15)
# Final score: 1.15
# Test of the FC
# Win/lose count 0/1.0. Average score (-1.0)
# Win/lose count 0.5/4.0. Average score (-2.25)
# Win/lose count 1.5/1.0. Average score (-1.3333333333333333)
# Win/lose count 0/0. Average score (-1.0)
# Win/lose count 1.0/5.0. Average score (-1.6)
# Win/lose count 0.5/1.0. Average score (-1.4166666666666667)
# Win/lose count 1.5/2.0. Average score (-1.2857142857142858)
# Win/lose count 0/5.0. Average score (-1.75)
# Win/lose count 0.5/2.0. Average score (-1.7222222222222223)
# Win/lose count 3.0/8.0. Average score (-2.05)
# Final score: -2.05
# -------------------- Temperature : 0.5 ---------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 4)                 2308
# =================================================================
# Total params: 21,412
# Trainable params: 21,412
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 14.0/5.0. Average score (9.0)
# Win/lose count 7.5/4.0. Average score (6.25)
# Win/lose count 16.5/4.0. Average score (8.333333333333334)
# Win/lose count 14.5/3.0. Average score (9.125)
# Win/lose count 6.5/2.0. Average score (8.2)
# Win/lose count 13.5/3.0. Average score (8.583333333333334)
# Win/lose count 4.5/2.0. Average score (7.714285714285714)
# Win/lose count 11.0/5.0. Average score (7.5)
# Win/lose count 10.5/7.0. Average score (7.055555555555555)
# Win/lose count 7.0/3.0. Average score (6.75)
# Final score: 6.75
# Test of the FC
# Win/lose count 8.0/7.0. Average score (1.0)
# Win/lose count 8.0/2.0. Average score (3.5)
# Win/lose count 7.5/5.0. Average score (3.1666666666666665)
# Win/lose count 8.5/5.0. Average score (3.25)
# Win/lose count 12.0/10.0. Average score (3.0)
# Win/lose count 6.0/4.0. Average score (2.8333333333333335)
# Win/lose count 6.0/6.0. Average score (2.4285714285714284)
# Win/lose count 4.5/2.0. Average score (2.4375)
# Win/lose count 7.5/6.0. Average score (2.3333333333333335)
# Win/lose count 11.5/5.0. Average score (2.75)
# Final score: 2.75
# -------------------- Temperature : 0.9 ---------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 5, 5, 32)          608
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_42 (Dense)             (None, 4)                 2308
# =================================================================
# Total params: 21,412
# Trainable params: 21,412
# Non-trainable params: 0
# _________________________________________________________________
# Test of the CNN
# Win/lose count 16.0/2.0. Average score (14.0)
# Win/lose count 24.5/3.0. Average score (17.75)
# Win/lose count 19.5/4.0. Average score (17.0)
# Win/lose count 19.5/0. Average score (17.625)
# Win/lose count 21.5/0. Average score (18.4)
# Win/lose count 29.0/0. Average score (20.166666666666668)
# Win/lose count 28.0/2.0. Average score (21.0)
# Win/lose count 16.0/0. Average score (20.375)
# Win/lose count 26.5/1.0. Average score (20.944444444444443)
# Win/lose count 8.5/0. Average score (19.7)
# Final score: 19.7
# Test of the FC
# Win/lose count 12.5/3.0. Average score (9.5)
# Win/lose count 13.0/1.0. Average score (10.75)
# Win/lose count 10.5/1.0. Average score (10.333333333333334)
# Win/lose count 12.5/3.0. Average score (10.125)
# Win/lose count 9.5/3.0. Average score (9.4)
# Win/lose count 10.0/1.0. Average score (9.333333333333334)
# Win/lose count 12.5/1.0. Average score (9.642857142857142)
# Win/lose count 15.5/0. Average score (10.375)
# Win/lose count 23.0/5.0. Average score (11.222222222222221)
# Win/lose count 9.5/0. Average score (11.05)
# Final score: 11.05

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action, train=True)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {:.1f}/{:.1f} ({:.1f})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(Environment):
    
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        super(EnvironmentExploring, self).__init__(grid_size=grid_size, 
                                                   max_time=max_time, 
                                                   temperature=temperature)
        self.malus_position = np.zeros_like(self.board)
    
   

    def act(self, action, train = False):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = 0
        if train:
            reward = -self.malus_position[self.x, self.y]
        self.malus_position[self.x, self.y] = 0.1 #we could write +=0.1 instead

        reward = reward + self.board[self.x, self.y]
        
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0
        
        self.malus_position = np.zeros((self.grid_size, self.grid_size))

        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore10.mp4'))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_45 (Conv2D)           (None, 5, 5, 32)          896
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 3, 3, 64)          18496
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 576)               0
# _________________________________________________________________
# dense_46 (Dense)             (None, 4)                 2308
# =================================================================
# Total params: 21,700
# Trainable params: 21,700
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 000/100 | Loss 0.0110 | Win/lose count 3.0/24.1 (-21.1)
# Epoch 001/100 | Loss 0.0222 | Win/lose count 6.5/20.2 (-13.7)
# Epoch 002/100 | Loss 0.0110 | Win/lose count 5.5/24.2 (-18.7)
# Epoch 003/100 | Loss 0.0121 | Win/lose count 7.0/21.5 (-14.5)
# Epoch 004/100 | Loss 0.0109 | Win/lose count 15.0/19.0 (-4.0)
# Epoch 005/100 | Loss 0.0105 | Win/lose count 8.5/19.0 (-10.5)
# Epoch 006/100 | Loss 0.0087 | Win/lose count 15.0/14.0 (1.0)
# Epoch 007/100 | Loss 0.0127 | Win/lose count 13.0/17.1 (-4.1)
# Epoch 008/100 | Loss 0.0058 | Win/lose count 12.0/16.6 (-4.6)
# Epoch 009/100 | Loss 0.0160 | Win/lose count 21.0/16.3 (4.7)
# Epoch 010/100 | Loss 0.0054 | Win/lose count 12.0/15.8 (-3.8)
# Epoch 011/100 | Loss 0.0122 | Win/lose count 18.0/16.7 (1.3)
# Epoch 012/100 | Loss 0.0155 | Win/lose count 15.5/14.7 (0.8)
# Epoch 013/100 | Loss 0.0113 | Win/lose count 17.0/13.0 (4.0)
# Epoch 014/100 | Loss 0.0213 | Win/lose count 19.0/12.6 (6.4)
# Epoch 015/100 | Loss 0.0242 | Win/lose count 16.5/11.6 (4.9)
# Epoch 016/100 | Loss 0.0125 | Win/lose count 15.5/15.6 (-0.1)
# Epoch 017/100 | Loss 0.0119 | Win/lose count 20.5/14.6 (5.9)
# Epoch 018/100 | Loss 0.0295 | Win/lose count 27.0/15.5 (11.5)
# Epoch 019/100 | Loss 0.0122 | Win/lose count 25.0/13.8 (11.2)
# Epoch 020/100 | Loss 0.0129 | Win/lose count 21.0/12.3 (8.7)
# Epoch 021/100 | Loss 0.0114 | Win/lose count 22.0/15.2 (6.8)
# Epoch 022/100 | Loss 0.0166 | Win/lose count 26.0/14.5 (11.5)
# Epoch 023/100 | Loss 0.0294 | Win/lose count 20.0/12.1 (7.9)
# Epoch 024/100 | Loss 0.0149 | Win/lose count 21.0/13.7 (7.3)
# Epoch 025/100 | Loss 0.0214 | Win/lose count 20.5/12.2 (8.3)
# Epoch 026/100 | Loss 0.0138 | Win/lose count 16.0/13.0 (3.0)
# Epoch 027/100 | Loss 0.0165 | Win/lose count 19.0/16.0 (3.0)
# Epoch 028/100 | Loss 0.0146 | Win/lose count 21.5/8.6 (12.9)
# Epoch 029/100 | Loss 0.0181 | Win/lose count 26.0/18.0 (8.0)
# Epoch 030/100 | Loss 0.0197 | Win/lose count 17.0/13.2 (3.8)
# Epoch 031/100 | Loss 0.0210 | Win/lose count 20.5/14.9 (5.6)
# Epoch 032/100 | Loss 0.0136 | Win/lose count 26.5/10.1 (16.4)
# Epoch 033/100 | Loss 0.0206 | Win/lose count 18.5/11.7 (6.8)
# Epoch 034/100 | Loss 0.0121 | Win/lose count 20.5/13.5 (7.0)
# Epoch 035/100 | Loss 0.0296 | Win/lose count 23.5/14.9 (8.6)
# Epoch 036/100 | Loss 0.0236 | Win/lose count 21.0/18.0 (3.0)
# Epoch 037/100 | Loss 0.0233 | Win/lose count 24.5/17.9 (6.6)
# Epoch 038/100 | Loss 0.0197 | Win/lose count 18.5/13.8 (4.7)
# Epoch 039/100 | Loss 0.0169 | Win/lose count 25.5/16.7 (8.8)
# Epoch 040/100 | Loss 0.0194 | Win/lose count 21.5/14.0 (7.5)
# Epoch 041/100 | Loss 0.0100 | Win/lose count 15.5/21.1 (-5.6)
# Epoch 042/100 | Loss 0.0359 | Win/lose count 19.5/16.4 (3.1)
# Epoch 043/100 | Loss 0.0381 | Win/lose count 17.0/23.0 (-6.0)
# Epoch 044/100 | Loss 0.0277 | Win/lose count 21.0/13.7 (7.3)
# Epoch 045/100 | Loss 0.0232 | Win/lose count 21.5/20.0 (1.5)
# Epoch 046/100 | Loss 0.0140 | Win/lose count 18.0/15.5 (2.5)
# Epoch 047/100 | Loss 0.0294 | Win/lose count 22.0/17.5 (4.5)
# Epoch 048/100 | Loss 0.0222 | Win/lose count 18.0/17.8 (0.2)
# Epoch 049/100 | Loss 0.0131 | Win/lose count 23.5/13.0 (10.5)
# Epoch 050/100 | Loss 0.0195 | Win/lose count 24.0/13.1 (10.9)
# Epoch 051/100 | Loss 0.0234 | Win/lose count 22.5/18.6 (3.9)
# Epoch 052/100 | Loss 0.0255 | Win/lose count 18.0/10.9 (7.1)
# Epoch 053/100 | Loss 0.0172 | Win/lose count 18.0/14.8 (3.2)
# Epoch 054/100 | Loss 0.0282 | Win/lose count 21.0/16.5 (4.5)
# Epoch 055/100 | Loss 0.0288 | Win/lose count 16.0/19.5 (-3.5)
# Epoch 056/100 | Loss 0.0239 | Win/lose count 21.0/13.0 (8.0)
# Epoch 057/100 | Loss 0.0296 | Win/lose count 20.5/14.0 (6.5)
# Epoch 058/100 | Loss 0.0339 | Win/lose count 22.5/12.9 (9.6)
# Epoch 059/100 | Loss 0.0197 | Win/lose count 18.0/17.5 (0.5)
# Epoch 060/100 | Loss 0.0328 | Win/lose count 20.0/15.7 (4.3)
# Epoch 061/100 | Loss 0.0209 | Win/lose count 20.0/14.4 (5.6)
# Epoch 062/100 | Loss 0.0274 | Win/lose count 22.0/13.1 (8.9)
# Epoch 063/100 | Loss 0.0175 | Win/lose count 17.0/13.2 (3.8)
# Epoch 064/100 | Loss 0.0170 | Win/lose count 16.0/16.7 (-0.7)
# Epoch 065/100 | Loss 0.0136 | Win/lose count 26.0/13.4 (12.6)
# Epoch 066/100 | Loss 0.0356 | Win/lose count 16.0/19.3 (-3.3)
# Epoch 067/100 | Loss 0.0132 | Win/lose count 20.0/20.4 (-0.4)
# Epoch 068/100 | Loss 0.0210 | Win/lose count 26.5/12.3 (14.2)
# Epoch 069/100 | Loss 0.0152 | Win/lose count 6.5/18.0 (-11.5)
# Epoch 070/100 | Loss 0.0188 | Win/lose count 26.0/16.0 (10.0)
# Epoch 071/100 | Loss 0.0139 | Win/lose count 11.5/17.8 (-6.3)
# Epoch 072/100 | Loss 0.0288 | Win/lose count 17.0/19.0 (-2.0)
# Epoch 073/100 | Loss 0.0186 | Win/lose count 24.5/22.8 (1.7)
# Epoch 074/100 | Loss 0.0330 | Win/lose count 16.5/17.6 (-1.1)
# Epoch 075/100 | Loss 0.0222 | Win/lose count 16.0/14.5 (1.5)
# Epoch 076/100 | Loss 0.0270 | Win/lose count 17.5/18.0 (-0.5)
# Epoch 077/100 | Loss 0.0215 | Win/lose count 20.0/13.2 (6.8)
# Epoch 078/100 | Loss 0.0393 | Win/lose count 16.5/16.0 (0.5)
# Epoch 079/100 | Loss 0.0214 | Win/lose count 16.0/18.0 (-2.0)
# Epoch 080/100 | Loss 0.0160 | Win/lose count 26.0/15.6 (10.4)
# Epoch 081/100 | Loss 0.0147 | Win/lose count 22.5/13.7 (8.8)
# Epoch 082/100 | Loss 0.0312 | Win/lose count 16.0/17.8 (-1.8)
# Epoch 083/100 | Loss 0.0237 | Win/lose count 16.5/17.1 (-0.6)
# Epoch 084/100 | Loss 0.0307 | Win/lose count 15.0/17.7 (-2.7)
# Epoch 085/100 | Loss 0.0318 | Win/lose count 18.0/14.0 (4.0)
# Epoch 086/100 | Loss 0.0208 | Win/lose count 19.0/13.9 (5.1)
# Epoch 087/100 | Loss 0.0147 | Win/lose count 16.5/15.2 (1.3)
# Epoch 088/100 | Loss 0.0149 | Win/lose count 14.5/19.1 (-4.6)
# Epoch 089/100 | Loss 0.0177 | Win/lose count 20.5/13.5 (7.0)
# Epoch 090/100 | Loss 0.0358 | Win/lose count 8.5/20.5 (-12.0)
# Epoch 091/100 | Loss 0.0152 | Win/lose count 24.5/11.8 (12.7)
# Epoch 092/100 | Loss 0.0305 | Win/lose count 23.5/16.0 (7.5)
# Epoch 093/100 | Loss 0.0145 | Win/lose count 12.0/17.5 (-5.5)
# Epoch 094/100 | Loss 0.0226 | Win/lose count 15.5/13.9 (1.6)
# Epoch 095/100 | Loss 0.0329 | Win/lose count 5.5/18.5 (-13.0)
# Epoch 096/100 | Loss 0.0143 | Win/lose count 17.5/19.3 (-1.8)
# Epoch 097/100 | Loss 0.0247 | Win/lose count 14.5/21.2 (-6.7)
# Epoch 098/100 | Loss 0.0167 | Win/lose count 12.0/18.8 (-6.8)
# Epoch 099/100 | Loss 0.0214 | Win/lose count 12.5/19.4 (-6.9)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore10.mp4'))
# Out:
# Win/lose count 22.5/9.0. Average score (13.5)
# Win/lose count 21.5/4.0. Average score (15.5)
# Win/lose count 14.0/4.0. Average score (13.666666666666666)
# Win/lose count 23.5/5.0. Average score (14.875)
# Win/lose count 21.0/9.0. Average score (14.3)
# Win/lose count 14.0/5.0. Average score (13.416666666666666)
# Win/lose count 17.0/7.0. Average score (12.928571428571429)
# Win/lose count 19.5/5.0. Average score (13.125)
# Win/lose count 14.0/4.0. Average score (12.777777777777779)
# Win/lose count 20.5/7.0. Average score (12.85)
# Win/lose count 17.5/8.0. Average score (12.545454545454545)
# Win/lose count 13.0/7.0. Average score (12.0)
# Win/lose count 16.5/3.0. Average score (12.115384615384615)
# Win/lose count 13.5/2.0. Average score (12.071428571428571)
# Win/lose count 25.0/2.0. Average score (12.8)
# Final score: 12.8
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# This new environment encourages the agent to explore more the board. That improves its preformances.
